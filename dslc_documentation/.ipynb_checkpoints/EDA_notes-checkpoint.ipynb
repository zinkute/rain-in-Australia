# %% [markdown]
# <span style="font-family:Cambria">
# To-do list after EDA:
#
# * Remove 2007 and 2008 year data (?) (Temperature)
# * Remove 2015 temperature data for Melbourne (?) (Temperature)
# </span>
